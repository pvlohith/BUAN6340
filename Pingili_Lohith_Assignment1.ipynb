# %%
# github link : https://github.com/pvlohith/BUAN6340

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Question
# ## 1)	Load in the appropriate csv file as a pandas dataframe (batting.csv)

# %%
df = pd.read_csv('batting.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#     playerID nameFirst     nameLast  birthYear  yearID  stint teamID lgID   G  \
# 0  abercda01     Frank  Abercrombie       1850    1871      1    TRO  NaN   1
# 1   addybo01       Bob         Addy       1842    1871      1    RC1  NaN  25
# 2  allisar01       Art      Allison       1849    1871      1    CL1  NaN  29
# 3  allisdo01      Doug      Allison       1846    1871      1    WS3  NaN  27
# 4  ansonca01       Cap        Anson       1852    1871      1    RC1  NaN  25
#
#     AB  ...    RBI   SB   CS  BB   SO  IBB  HBP  SH  SF  GIDP
# 0    4  ...    0.0  0.0  0.0   0  0.0  NaN  NaN NaN NaN   NaN
# 1  118  ...   13.0  8.0  1.0   4  0.0  NaN  NaN NaN NaN   NaN
# 2  137  ...   19.0  3.0  1.0   2  5.0  NaN  NaN NaN NaN   NaN
# 3  133  ...   27.0  1.0  1.0   0  2.0  NaN  NaN NaN NaN   NaN
# 4  120  ...   16.0  6.0  2.0   2  1.0  NaN  NaN NaN NaN   NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# # Question
# ## 2)	Print out the dimensions and info about the dataframe you just created

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102816 entries, 0 to 102815
# Data columns (total 25 columns):
# playerID     102816 non-null object
# nameFirst    102816 non-null object
# nameLast     102816 non-null object
# birthYear    102816 non-null int64
# yearID       102816 non-null int64
# stint        102816 non-null int64
# teamID       102816 non-null object
# lgID         102079 non-null object
# G            102816 non-null int64
# AB           102816 non-null int64
# R            102816 non-null int64
# H            102816 non-null int64
# 2B           102816 non-null int64
# 3B           102816 non-null int64
# HR           102816 non-null int64
# RBI          102392 non-null float64
# SB           101516 non-null float64
# CS           79360 non-null float64
# BB           102816 non-null int64
# SO           94978 non-null float64
# IBB          66251 non-null float64
# HBP          100006 non-null float64
# SH           96478 non-null float64
# ...

# %% [markdown]
# # Adding columns PA, Average and OBP
# ## PA(Plate Appearances) = AB+BB+IBB+SH+SF
# ## Average = H/AB
# ## OBP(on base percentage) = (H+BB+IBB+SH+SF)/AB

# %%
df['PA']=df['AB']+df['BB']+df['IBB']+df['SH']+df['SF']
df['Average'] = df['H']/df['AB']
df['OBP'] = (df['H']+df['BB']+df['IBB']+df['SH']+df['SF'])/df['AB']

# %%
df.head()
# Out:
#     playerID nameFirst     nameLast  birthYear  yearID  stint teamID lgID   G  \
# 0  abercda01     Frank  Abercrombie       1850    1871      1    TRO  NaN   1
# 1   addybo01       Bob         Addy       1842    1871      1    RC1  NaN  25
# 2  allisar01       Art      Allison       1849    1871      1    CL1  NaN  29
# 3  allisdo01      Doug      Allison       1846    1871      1    WS3  NaN  27
# 4  ansonca01       Cap        Anson       1852    1871      1    RC1  NaN  25
#
#     AB ...   BB   SO  IBB  HBP  SH  SF  GIDP  PA   Average  OBP
# 0    4 ...    0  0.0  NaN  NaN NaN NaN   NaN NaN  0.000000  NaN
# 1  118 ...    4  0.0  NaN  NaN NaN NaN   NaN NaN  0.271186  NaN
# 2  137 ...    2  5.0  NaN  NaN NaN NaN   NaN NaN  0.291971  NaN
# 3  133 ...    0  2.0  NaN  NaN NaN NaN   NaN NaN  0.330827  NaN
# 4  120 ...    2  1.0  NaN  NaN NaN NaN   NaN NaN  0.325000  NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# # Question
# ## 3)	How many players have hit 40 or more HRs in one single season?

# %%
q3 = df[df['HR']>=40]
q3['playerID'].nunique()
# Out:
# 142

# %% [markdown]
# # Question
# ## 4)	How many players have hit more than 600 HRs for their career? (Dataframe)

# %%
q4=df.groupby('playerID')['HR'].agg('sum')
q4[q4>600]
# Out:
# playerID
# aaronha01    755
# bondsba01    762
# griffke02    630
# mayswi01     660
# rodrial01    696
# ruthba01     714
# sosasa01     609
# thomeji01    612
# Name: HR, dtype: int64

# %% [markdown]
# # Question5
# ## 5)	How many players have hit 40 2Bs, 10 3Bs, 200 Hits, and 30 HRs (inclusive) in one season? (Number Only)

# %%
q5 = df[(df['2B']>=40) & (df['3B']>=10) & (df['H'] >=200) & (df['HR']>=30)]
q5['playerID'].nunique()
# Out:
# 11

# %% [markdown]
# # Question6
# ## 6)	How many players have had 100 or more SBs in a season? (Dataframe)

# %%
q6 = df[df['SB']>=100]
print(q6)
# Out:
#         playerID nameFirst   nameLast  birthYear  yearID  stint teamID lgID  \
# 3473   brownpe01      Pete   Browning       1861    1887      1    LS2   AA
# 3501   comisch01   Charlie   Comiskey       1859    1887      1    SL4   AA
# 3546   fogarji01       Jim    Fogarty       1864    1887      1    PHI   NL
# 3617   lathaar01     Arlie     Latham       1860    1887      1    SL4   AA
# 3667   nicolhu01      Hugh      Nicol       1858    1887      1    CN2   AA
# 3764    wardjo01      John       Ward       1860    1887      1    NY1   NL
# 3975   lathaar01     Arlie     Latham       1860    1888      1    SL4   AA
# 4014   nicolhu01      Hugh      Nicol       1858    1888      1    CN2   AA
# 4278   hamilbi01     Billy   Hamilton       1866    1889      1    KC2   AA
# 4696   hamilbi01     Billy   Hamilton       1866    1890      1    PHI   NL
# 5086   brownto01       Tom      Brown       1860    1891      1    BS2   AA
# ...

# %% [markdown]
# # Question7
# ## 7)	How many players in the 1960s have hit more than 200 HRs? (Dataframe)

# %%
q7_1 = df[(df['yearID'] <= 1969) & (df['yearID'] >= 1960)]
q7_2 =q7_1.groupby('playerID')['HR'].agg('sum')
q7_2[q7_2 >200]
# Out:
# playerID
# aaronha01    375
# allisbo01    225
# bankser01    269
# cashno01     278
# cepedor01    254
# colavro01    245
# howarfr01    288
# kalinal01    210
# killeha01    393
# mantlmi01    256
# marisro01    217
# matheed01    213
# mayswi01     350
# mccovwi01    300
# powelbo01    202
# robinfr02    316
# santoro01    253
# willibi01    249
# yastrca01    202
# Name: HR, dtype: int64

# %% [markdown]
# # Question8
# ## 8)	Who has hit the most HRs in history? (Dataframe)

# %%
q8=df.groupby('playerID')['HR'].agg('sum')
q8.nlargest(1)
# Out:
# playerID
# bondsba01    762
# Name: HR, dtype: int64

# %% [markdown]
# # Question9
# ## 9)	Who had the most hits in the 1970s? (Dataframe)

# %%
q9 = df[(df['yearID']>=1970) & (df['yearID']<=1979)]
q9_1=q9.groupby('playerID')['H'].agg('sum')
q9_1.nlargest(1)
# Out:
# playerID
# rosepe01    2045
# Name: H, dtype: int64

# %% [markdown]
# # Question10
# ## 10)	Top 5 highest OBP (on base percentage) with at least 500 PAs in 1977?  (Dataframe)

# %%
q10=df[(df['PA']>=500) & (df['yearID']==1977)]
(q10.sort_values(by='OBP',ascending=False)).head(5)
# Out:
#         playerID nameFirst   nameLast  birthYear  yearID  stint teamID lgID  \
# 55273  singlke01       Ken  Singleton       1947    1977      1    BAL   AL
# 55280  smithre06    Reggie      Smith       1945    1977      1    LAN   NL
# 55329  tenacge01      Gene     Tenace       1946    1977      1    SDN   NL
# 54820  hargrmi01      Mike   Hargrove       1949    1977      1    TEX   AL
# 54603  carewro01       Rod      Carew       1945    1977      1    MIN   AL
#
#          G   AB    ...      BB     SO   IBB   HBP   SH   SF  GIDP     PA  \
# 55273  152  536    ...     107  101.0  13.0   2.0  0.0  6.0  15.0  662.0
# 55280  148  488    ...     104   76.0  11.0   3.0  1.0  7.0   5.0  611.0
# 55329  147  437    ...     125  119.0  10.0  13.0  2.0  4.0   5.0  578.0
# 54820  153  525    ...     103   59.0   7.0   6.0  8.0  6.0  13.0  649.0
# 54603  155  616    ...      69   55.0  15.0   3.0  1.0  5.0   6.0  706.0
#
#         Average       OBP
# 55273  0.328358  0.563433
# ...

# %% [markdown]
# # Question11
# ## 11)	Top 8 highest averages in 2013 with at least 300 PAs? (Dataframe)

# %%
q11=df[(df['PA']>=300) & (df['yearID']==2013)]
(q11.sort_values(by='Average',ascending=False)).head(8)
# Out:
#         playerID nameFirst nameLast  birthYear  yearID  stint teamID lgID  \
# 97188  cabremi01    Miguel  Cabrera       1983    2013      1    DET   AL
# 98062  ramirha01    Hanley  Ramirez       1983    2013      1    LAN   NL
# 97300  cuddymi01   Michael  Cuddyer       1979    2013      1    COL   NL
# 97825  mauerjo01       Joe    Mauer       1983    2013      1    MIN   AL
# 98293  troutmi01      Mike    Trout       1991    2013      1    LAA   AL
# 97651  johnsch05     Chris  Johnson       1984    2013      1    ATL   NL
# 97437  freemfr01   Freddie  Freeman       1989    2013      1    ATL   NL
# 98043   puigya01    Yasiel     Puig       1990    2013      1    LAN   NL
#
#          G   AB    ...      BB     SO   IBB   HBP   SH   SF  GIDP     PA  \
# 97188  148  555    ...      90   94.0  19.0   5.0  0.0  2.0  19.0  666.0
# 98062   86  304    ...      27   52.0   3.0   3.0  0.0  2.0   5.0  336.0
# 97300  130  489    ...      46  100.0   5.0   2.0  0.0  3.0  13.0  543.0
# ...

# %% [markdown]
# # Question12
# ## 12)	Leaders in hits from 1940 up to and including 1949. (Dataframe)

# %%
q12=pd.DataFrame()
for yearID in range(1940,1950):
    q12_1=df[df['yearID'] == yearID]
    q12_2=(q12_1.sort_values(by='H', ascending=False)).head(1)
    q12=q12.append(q12_2)
q12
# Out:
#         playerID nameFirst    nameLast  birthYear  yearID  stint teamID lgID  \
# 29084  radclri01       Rip    Radcliff       1906    1940      1    SLA   AL
# 29747  travice01     Cecil      Travis       1913    1941      1    WS1   AL
# 30191  peskyjo01    Johnny       Pesky       1919    1942      1    BOS   AL
# 30709  musiast01      Stan      Musial       1920    1943      1    SLN   NL
# 31389  stirnsn01    Snuffy  Stirnweiss       1918    1944      1    NYA   AL
# 31720  holmeto01     Tommy      Holmes       1917    1945      1    BSN   NL
# 32499  musiast01      Stan      Musial       1920    1946      1    SLN   NL
# 33128  peskyjo01    Johnny       Pesky       1919    1947      1    BOS   AL
# 33671  musiast01      Stan      Musial       1920    1948      1    SLN   NL
# 34242  musiast01      Stan      Musial       1920    1949      1    SLN   NL
#
#          G   AB ...    BB    SO  IBB  HBP    SH  SF  GIDP  PA   Average  OBP
# ...

# %% [markdown]
# # Question13
# ## 13)	Who led MLB with the most hits the most times?  And how many times?  (Dataframe, Number)

# %%
q13=pd.DataFrame()
for yearID in range(1871,2017):
    q13_1=df[df['yearID'] == yearID]
    q13_2=(q13_1.sort_values(by='H', ascending=False)).head(1)
    q13=q13.append(q13_2)
q13.groupby('playerID').size().nlargest(1)
# Out:
# playerID
# suzukic01    6
# dtype: int64

# %% [markdown]
# # Question14
# ## 14) Which players have played the most games for their careers?  Top 5, descending by games played presented as a dataframe

# %%
q14=pd.DataFrame(df.groupby('playerID').size().nlargest(5))
q14
# Out:
#             0
# playerID
# mcguide01  31
# henderi01  29
# newsobo01  29
# johnto01   28
# kaatji01   28

# %% [markdown]
# # Question15
# ## 15) How many players have had more than 3000 hits for their careers while also hitting 500 or more HRs?  Just a number is okay here

# %%
q15=df.groupby('playerID')['HR','H'].agg('sum')
len(q15[(q15['HR']>=500) & (q15['H']>3000)])
# Out:
# 5

# %% [markdown]
# # Question16
# ## 16) How many HRs were hit during the entire 1988 season?  Just a number is okay here

# %%
q16=df[df['yearID']==1988]
print(q16['HR'].sum())
# Out:
# 3180

# %% [markdown]
# # Question17
# ## 17) Please filter out and show me the top 3 average seasons by Wade Boggs during his career in seasons in which he had at least 500 ABs. I would like a dataframe sorted by average.

# %%
q17=(df[(df['nameFirst']=='Wade') & (df['nameLast']=='Boggs') & (df['AB']>=500)])
q17.sort_values(by='Average',ascending=False).head(3)
# Out:
#         playerID nameFirst nameLast  birthYear  yearID  stint teamID lgID  \
# 62316  boggswa01      Wade    Boggs       1958    1985      1    BOS   AL
# 65391  boggswa01      Wade    Boggs       1958    1988      1    BOS   AL
# 64335  boggswa01      Wade    Boggs       1958    1987      1    BOS   AL
#
#          G   AB    ...      BB    SO   IBB  HBP   SH   SF  GIDP     PA  \
# 62316  161  653    ...      96  61.0   5.0  4.0  3.0  2.0  20.0  759.0
# 65391  155  584    ...     125  34.0  18.0  3.0  0.0  7.0  23.0  734.0
# 64335  147  551    ...     105  48.0  19.0  2.0  1.0  8.0  13.0  684.0
#
#         Average       OBP
# 62316  0.367534  0.529862
# 65391  0.366438  0.623288
# 64335  0.362976  0.604356
#
# [3 rows x 28 columns]

# %% [markdown]
# # Question18
# ## 18)Please filter out the top OBPs for the 1995 season with at least 400 PAs, sorted by OBP.  I would like a dataframe for this

# %%
q18=df[(df['PA']>=400)&(df['yearID']==1995)].sort_values(by='OBP',ascending=False)
q18.head()
# Out:
#         playerID nameFirst  nameLast  birthYear  yearID  stint teamID lgID  \
# 73996  thomafr04     Frank    Thomas       1968    1995      1    CHA   AL
# 73578  martied01     Edgar  Martinez       1963    1995      1    SEA   AL
# 73611  mcgwima01      Mark   McGwire       1963    1995      1    OAK   AL
# 73002  bondsba01     Barry     Bonds       1964    1995      1    SFN   NL
# 73145  davisch01     Chili     Davis       1960    1995      1    CAL   AL
#
#          G   AB    ...      BB    SO   IBB   HBP   SH    SF  GIDP     PA  \
# 73996  145  493    ...     136  74.0  29.0   6.0  0.0  12.0  14.0  670.0
# 73578  145  511    ...     116  87.0  19.0   8.0  0.0   4.0  11.0  650.0
# 73611  104  317    ...      88  77.0   5.0  11.0  0.0   6.0   9.0  416.0
# 73002  144  506    ...     120  83.0  22.0   5.0  0.0   4.0  12.0  652.0
# 73145  119  424    ...      89  79.0  12.0   0.0  0.0   9.0  12.0  534.0
#
#         Average       OBP
# 73996  0.308316  0.667343
# ...

# %% [markdown]
# # Question19
# ## 19)Please filter out the top OBPs for the 1995 season with at least 400 PAs, sorted by OBP.  I would like a dataframe for this

# %%
q19=df[(df['yearID']==1995) & (df['PA']>=400)].sort_values(by='OBP',ascending=False)
q19.head(10)
# Out:
#         playerID nameFirst  nameLast  birthYear  yearID  stint teamID lgID  \
# 73996  thomafr04     Frank    Thomas       1968    1995      1    CHA   AL
# 73578  martied01     Edgar  Martinez       1963    1995      1    SEA   AL
# 73611  mcgwima01      Mark   McGwire       1963    1995      1    OAK   AL
# 73002  bondsba01     Barry     Bonds       1964    1995      1    SFN   NL
# 73145  davisch01     Chili     Davis       1960    1995      1    CAL   AL
# 73560  magadda01      Dave   Magadan       1962    1995      1    HOU   NL
# 73999  thomeji01       Jim     Thome       1970    1995      1    CLE   AL
# 72937  baineha01    Harold    Baines       1959    1995      1    BAL   AL
# 74080  weisswa01      Walt     Weiss       1963    1995      1    COL   NL
# 72999  boggswa01      Wade     Boggs       1958    1995      1    NYA   AL
#
#          G   AB    ...      BB     SO   IBB   HBP   SH    SF  GIDP     PA  \
# ...

# %% [markdown]
# # Question20
# ## 20) How many players have hit 30 or more HRs in season while also stealing (SB) 30 more or bases?  A number is okay here

# %%
q20=df[(df['HR']>=30) & (df['SB']>=30)]
print(len(q20))
# Out:
# 58

# %% [markdown]
# # Question21
# ## 21) Who had the highest OBP is 1986 with at least 400 PAs? (Dataframe)

# %%
q21=df[(df['yearID']==1986) & (df['PA']>=400)].sort_values(by='OBP',ascending=False)
q21.head(1)
# Out:
#         playerID nameFirst nameLast  birthYear  yearID  stint teamID lgID  \
# 63320  boggswa01      Wade    Boggs       1958    1986      1    BOS   AL
#
#          G   AB    ...      BB    SO   IBB  HBP   SH   SF  GIDP     PA  \
# 63320  149  580    ...     105  44.0  14.0  0.0  4.0  4.0  11.0  707.0
#
#         Average       OBP
# 63320  0.356897  0.575862
#
# [1 rows x 28 columns]

# %% [markdown]
# # Question22
# ## 22) Same question but for 1997 and only in the NL (check league ID)? (Dataframe)

# %%
q22=df[(df['yearID']==1997) & (df['PA']>=400) & (df['lgID']=='NL')].sort_values(by='OBP',ascending=False)
q22.head(1)
# Out:
#         playerID nameFirst nameLast  birthYear  yearID  stint teamID lgID  \
# 75505  bondsba01     Barry    Bonds       1964    1997      1    SFN   NL
#
#          G   AB    ...      BB    SO   IBB  HBP   SH   SF  GIDP     PA  \
# 75505  159  532    ...     145  87.0  34.0  8.0  0.0  5.0  13.0  716.0
#
#         Average       OBP
# 75505  0.291353  0.637218
#
# [1 rows x 28 columns]

# %% [markdown]
# # Question23
# ## 23) Who had more than the league average HRs in 2012 (filter out all players with less 500 PAs)? (Dataframe)

# %%
q23=df[df['yearID']==2012]
q23[(q23['PA']>500) & (q23['HR'] > (q23['HR'].mean()))]
# Out:
#         playerID  nameFirst    nameLast  birthYear  yearID  stint teamID lgID  \
# 95603  ackledu01     Dustin      Ackley       1988    2012      1    SEA   AL
# 95616  alonsyo01     Yonder      Alonso       1987    2012      1    SDN   NL
# 95617  altuvjo01       Jose      Altuve       1990    2012      1    HOU   NL
# 95619  alvarpe01      Pedro     Alvarez       1987    2012      1    PIT   NL
# 95629   aokino01       Nori        Aoki       1982    2012      1    MIL   NL
# 95641  avilemi01       Mike      Aviles       1981    2012      1    BOS   AL
# 95645  aybarer01      Erick       Aybar       1984    2012      1    LAA   AL
# 95659  barneda01     Darwin      Barney       1985    2012      1    CHN   NL
# 95678  beckhgo01     Gordon     Beckham       1986    2012      1    CHA   AL
# 95687  beltrad01     Adrian      Beltre       1979    2012      1    TEX   AL
# 95688  beltrca01     Carlos     Beltran       1977    2012      1    SLN   NL
# ...

# %% [markdown]
# # Question24
# ## 24) Who is the youngest player to hit 50 or more HRs in a single season? (Dataframe)

# %%
q24=df[df['HR']>=50]
q24['age']=q24['yearID']-q24['birthYear']
q24.sort_values(by='age',ascending=True).head(1)
# Out:
# C:\Users\pvloh\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         playerID nameFirst nameLast  birthYear  yearID  stint teamID lgID  \
# 89082  fieldpr01    Prince  Fielder       1984    2007      1    MIL   NL
#
#          G   AB ...      SO   IBB   HBP   SH   SF  GIDP     PA   Average  \
# 89082  158  573 ...   121.0  21.0  14.0  0.0  4.0   9.0  688.0  0.287958
#
#             OBP  age
# 89082  0.488656   23
#
# [1 rows x 29 columns]

# %% [markdown]
# # Question25
# ## 25) Who are the five youngest players to hit 300 or more HRs for their career? (Dataframe)

# %%
players=df['playerID'].unique()
df['age']=df['yearID']-df['birthYear']
df['HR_total']=df.groupby('playerID')['HR'].cumsum()
q25=df[df['HR_total']>300]
q25=q25.groupby('playerID',as_index=False)['age'].min()
q25.sort_values(by="age").head(5)
# Out:
#       playerID  age
# 69   jonesan01   28
# 110  rodrial01   28
# 104  pujolal01   28
# 97     ottme01   28
# 46    foxxji01   28

# %% [markdown]
# # Bonus Question1
# ## Graph total HRs per season using bar graph

# %%
#Line graph is used as it better visualizes the data
q1=pd.DataFrame(df.groupby('yearID',as_index=False)['HR'].agg('sum'))
plt.plot(q1['yearID'] ,q1['HR'])
plt.xlabel('yearID')
plt.ylabel('Total Number of HR scored')
plt.title('Number of HR scored per season')
plt.show()

# %% [markdown]
# # Bonus Question2
# ## Using a line graph please graph the average HRs per AB (think about this) per season
